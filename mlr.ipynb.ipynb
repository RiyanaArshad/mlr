# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
print(os.listdir(r'C:\Users\hp\Downloads'))
# Out:
# ["'Certificate of Attendance (RH124-9.0)(RED HAT).pdf'-output.pdf", '1736137563PMC2414_CC_Syllabus.pdf', '1736744844PMC2414_Mod_1_Notes (1).docx', '1736744862mod_1_PMC2414_CC (1).pptx', '1739328578Module_3_ppt (1).pptx', '1739328578Module_3_ppt.pptx', '1739328598Module_3_Notes.pdf', 'ABC ID- MCA 2024 Batch.xlsx', 'AnyDesk.exe', 'apache-jmeter-5.6.3.tgz', 'Backend Development.pdf', 'data_preprocessing_template.py', 'desktop.ini', 'DocScanner 14-Jan-2025 8-03\u202fpm.pdf', 'DocScanner 22-Jan-2025 9-20\u202fpm.pdf', 'Documents - Shortcut.lnk', 'Git-2.47.1-64-bit.exe', 'gitignore', 'Hielo-1.0.0.zip', 'house_price_dataset.xlsx', 'hw -8.pdf', 'id proof.jpeg', 'ilovepdf_merged.pdf', 'jdk-21_windows-x64_bin.msi', 'jdk-23.0.1_doc-all.zip', 'jdk-23_windows-x64_bin (1).exe', 'jdk-23_windows-x64_bin.exe', 'Knowledge_Graphs_Semantic_Search (1).docx', 'Medical History Tracker.pdf', 'MLR (1).ipynb', 'MLR.ipynb', 'mlr_dataset.csv', 'ML_project', 'ML_project.zip', 'mongodb-windows-x86_64-8.0.5-signed.msi', 'mongosh-2.4.2-win32-x64.zip', 'mysql-installer-web-community-8.0.40.0.msi', 'Network-Service-Tiers.pptx', 'python assignment.pdf', 'python-3.12.0-amd64.exe', 'python-3.13.0-amd64.exe', 'python-3.13.1-amd64.exe', 'reciept nptel.pdf', 'Screenshot (38).png', 'screen_recorder_setup.exe', 'signature.jpeg', 'Simple Linear Regression.ipynb', 'splnproc1703.docm', 'Structure of a Review Paper.docx', 'System Design and Architecture.pdf', 'thonny-4.1.6.exe', 'uml diagrams for Bus booking system.pdf', 'VSCodeUserSetup-x64-1.94.2.exe', 'WhatsApp Image 2025-03-06 at 1.28.54 PM.jpeg', 'WhatsApp Image 2025-03-16 at 12.38.47 PM.jpeg']

# %%
dataset=pd.read_csv(r'C:\Users\hp\Desktop\MLR\data.csv')

# %%
print(dataset.columns)
print(dataset.shape)
# Out:
# Index(['Size (sq ft)', 'Bedrooms', 'Age (years)', 'Price ($)'], dtype='object')
# (10, 4)

# %%
dataset
# Out:
#    Size (sq ft)  Bedrooms  Age (years)  Price ($)
# 0           850         2           10     150000
# 1           900         2            8     165000
# 2          1100         3            6     180000
# 3          1200         3           12     195000
# 4          1350         3           15     210000
# 5          1500         4            5     230000
# 6          1600         4            8     250000
# 7          1750         4            7     270000
# 8          1850         5           10     290000
# 9          2000         5            3     310000

# %%
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,1]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[1])], remainder='passthrough')
X=np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[1.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 8.50e+02, 1.00e+01],
#        [1.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 9.00e+02, 8.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00, 1.10e+03, 6.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00, 1.20e+03, 1.20e+01],
#        [0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00, 1.35e+03, 1.50e+01],
#        [0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 1.50e+03, 5.00e+00],
#        [0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 1.60e+03, 8.00e+00],
#        [0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 1.75e+03, 7.00e+00],
#        [0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00, 1.85e+03, 1.00e+01],
#        [0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00, 2.00e+03, 3.00e+00]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([4., 3., 2., 4., 3.])

# %%
regressor.score(X,y)
# Out:
# 0.2380952380951723
